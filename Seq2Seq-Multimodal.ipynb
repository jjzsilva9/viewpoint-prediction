# %% [markdown]
# <h1>NN Model</h1>

# %%
from pycocotools.coco import COCO
import matplotlib
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as functions
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset
#import torchvision
from torchvision import transforms
import re

# %%
print("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# cuda

# %%
DATADIR = "cocodoom/"
USED_RUNS = ["run1", "run2", "run3"]

dataSplit, TRAIN_RUN = "run-full-train", "run1"

annFile = '{}{}.json'.format(DATADIR,dataSplit)

# %%
coco_train = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=22.88s)
# creating index...
# index created!
# Done (t=22.94s)
# creating index...
# index created!

# %%
dataSplit, VAL_RUN = "run-full-val", "run2"

annFile = '{}{}.json'.format(DATADIR,dataSplit)

# %%
coco_val = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=20.82s)
# creating index...
# index created!
# Done (t=20.81s)
# creating index...
# index created!

# %%
dataSplit, TEST_RUN = "run-full-test", "run3"

annFile = '{}{}.json'.format(DATADIR,dataSplit)

# %%
coco_test = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=11.72s)
# creating index...
# index created!
# Done (t=11.72s)
# creating index...
# index created!

# %%
player_positions = {"run1":[], "run2":[], "run3":[]}
motion_vectors = {"run1":[], "run2":[], "run3":[]}

for run in USED_RUNS:
    with open(DATADIR+run+"/log.txt", 'r') as log_file:
        for line in log_file:
            if "player" in line:
                line = line.strip()
                tic, stats = line.split("player:")
                x, y, z, angle = stats.split(",")
    
                # Store position in the dictionary
                player_positions[run].append((float(x), float(y), float(z), float(angle)))
                if len(player_positions[run]) >= 2:
                    player_position = player_positions[run][-1]
                    prev_player_position = player_positions[run][-2]
                    
                    dx = player_position[0] - prev_player_position[0]
                    dy = player_position[1] - prev_player_position[1]
                    dz = player_position[2] - prev_player_position[2]
                    dangle = np.pi - abs(abs(player_position[3] - prev_player_position[3]) - np.pi)
                    
                    dx_relative = dx * np.cos(2 * np.pi - prev_player_position[3]) + dy * np.cos(prev_player_position[3] - 1/2 * np.pi)
                    dy_relative = dx * np.sin(2 * np.pi - prev_player_position[3]) + dy * np.sin(prev_player_position[3] - 1/2 * np.pi)
                    motion_vector = (dx_relative, dy_relative, dz, dangle)
                    motion_vectors[run].append(motion_vector)

# %%
class DoomMotionDataset(Dataset):
    def __init__(self, coco, run, input_window, prediction_window, transform=None):
        self.coco = coco
        self.run = run
        self.img_ids = self.coco.getImgIds()
        self.transform = transform
        self.input_window = input_window
        self.prediction_window = prediction_window

    def __len__(self):
        return len(self.img_ids)

    def fullSegmentationFormat(self, rgb_filename):
        seg_image = self.load_image(self.getSegmentationMask(DATADIR + rgb_filename))
        if seg_image == None:
            return seg_image
        seg_class_map = self.color_to_index(seg_image)
        seg_class_one_hot = functions.one_hot(seg_class_map, num_classes=4).to(dtype=torch.float).permute(2, 0, 1)
        return seg_class_one_hot

    def fullDepthFormat(self, rgb_filename):
        depth_mask = self.load_image(self.getDepthMask(DATADIR + rgb_filename))
        if depth_mask == None:
            return depth_mask
        depth_mask = torch.tensor(depth_mask, dtype=torch.float32)
        return depth_mask

    def getSegmentationMask(self, rgb_filename):
        return rgb_filename.replace("rgb", "objects")

    def getDepthMask(self, rgb_filename):
        return rgb_filename.replace("rgb", "depth")

    def color_to_index(self, segmentation_image):
        # Map colors to class indices
        r, g, b = segmentation_image
        pixel_values = r + (g *  2**8) + (b * 2**16)  # From cocodoom documentation, converts to an object id

        class_map = torch.full_like(pixel_values, 3, dtype=torch.long)

        sky = (1 << 23) + 0
        horizontal = (1 << 23) + 1
        vertical = (1 << 23) + 2
        
        class_map[x == sky] = 0
        class_map[x == horizontal] = 1
        class_map[x == vertical] = 2
        return class_map

    def load_image(self, path):
        if os.path.exists(path):
            img = Image.open(path)
            return transforms.ToTensor()(img)
        return None

    def __getitem__(self, idx):
        # Load the RGB image
        rgb_filename = self.coco.loadImgs(self.img_ids[idx])[0]['file_name']
        print(rgb_filename)
        tic = int(rgb_filename.replace(".png", "").split("/")[-1])
        next_tic = tic+1
        previous_tic = tic-1
        prev_motion_vectors = []
        next_motion_vectors = []
        prev_seg = []
        prev_dep = []

        for t in range(input_window, 0, -1):
            if tic-t < 0:
                prev_motion_vectors.append(motion_vectors[self.run][0])
                prev_filename = self.coco.loadImgs(self.img_ids[0])[0]['file_name']
                seg = self.fullSegmentationFormat(prev_filename)
                dep = self.fullDepthFormat(prev_filename)
                prev_seg.append(seg)
                prev_dep.append(dep)
                continue
            elif tic-t >= len(motion_vectors[self.run]):
                prev_motion_vectors.append(motion_vectors[self.run][-1])
                prev_filename = self.coco.loadImgs(self.img_ids[-1])[0]['file_name']
                seg = self.fullSegmentationFormat(prev_filename)
                dep = self.fullDepthFormat(prev_filename)
                prev_seg.append(seg)
                prev_dep.append(dep)
                continue
            prev_motion_vectors.append(motion_vectors[self.run][tic-t])
            prev_filename = rgb_filename[:-10] + str(max(tic - t, 2)).rjust(6, "0") + ".png"
            # run1/map01/rgb/000002.png
            if os.path.exists(DATADIR + prev_filename):
                seg = self.fullSegmentationFormat(prev_filename)
                #print(f"seg shape: {seg.shape}")
                dep = self.fullDepthFormat(prev_filename)
                #print(f"dep shape: {dep.shape}")
                prev_seg.append(seg)
                prev_dep.append(dep)
            else:
                prev_seg.append(torch.zeros((4, 200, 320)))
                prev_dep.append(torch.zeros((1, 200, 320)))
                

        for t in range(1, prediction_window+1):
            if tic+t >= len(motion_vectors[self.run]):
                next_motion_vectors.append(motion_vectors[self.run][-1])
                continue
            next_motion_vectors.append(motion_vectors[self.run][tic+t])

        # if dx > 1000:
        #     print(f"idx: {idx}")
        #     print(f"rgb_filename: {rgb_filename}")
        #     print(f"tic: {tic}")
        #     print(f"next_tic: {next_tic}")
        #     print(f"previous_tic: {previous_tic}")
        #     print(f"Sus {idx}")
        #     print(f"prev_player_position: {prev_player_position}")
        #     print(f"player_position: {player_position}")
        #     print(f"next_player_position: {next_player_position}")
        #     print(f"prev_motion_vector: {prev_motion_vector}")
        #     print(f"next_motion_vector: {next_motion_vector}")

        #print(prev_motion_vectors)
        #print(next_motion_vectors)
            
        prev_motion_vectors = torch.tensor(prev_motion_vectors, dtype=torch.float32)
        next_motion_vectors = torch.tensor(next_motion_vectors, dtype=torch.float32)
        #print(len(prev_seg))
        prev_seg = torch.stack(prev_seg)
        prev_dep = torch.stack(prev_dep)
        
        return {"prev_motion" : prev_motion_vectors, "next_motion" : next_motion_vectors, "previous_seg" : prev_seg, "previous_dep" : prev_dep}

# %%
class NeuralNetwork(nn.Module):
  def __init__(self, batch_size, input_length, sequence_length, activation_function=functions.relu, device=torch.device("cpu")):
    super(NeuralNetwork, self).__init__()
    self.batch_size = batch_size
    self.input_length = input_length
    self.sequence_length = sequence_length

    # Encoder
    # Conv layers
    self.conv_seg = nn.Conv2d(4, 1, kernel_size=3, stride=2, padding=1, bias=False).to(device)
    self.conv_dep = nn.Conv2d(1, 1, kernel_size=3, stride=2, padding=1, bias=False).to(device)

    self.motion_fc = nn.Linear(4, 32).to(device)
      
    # Pre-fusion LSTMs
    self.vis_LSTM = nn.LSTM(input_size=32000, hidden_size=256, batch_first=True).to(device)
    self.inertia_LSTM = nn.LSTM(input_size=32, hidden_size=256, batch_first=True).to(device)

    # Fusion LSTM
    self.fusion_LSTM = nn.LSTM(input_size=512, hidden_size=256, batch_first=True).to(device)

    # Decoder
    self.de_motion_fc = nn.Linear(4, 32).to(device)
    self.de_vis_LSTM = nn.LSTM(input_size=32, hidden_size=256, batch_first=True).to(device) #Unsure what the input size of this should be as it actually receives nothing
    self.de_inertia_LSTM = nn.LSTM(input_size=32, hidden_size=256, batch_first=True).to(device)
    self.de_fusion_LSTM = nn.LSTM(input_size=512, hidden_size=256, batch_first=True).to(device)
    self.output_fc = nn.Linear(256, 4).to(device)

  def forward(self, segmentation, depth, prev_motion):
    hidden_vis = None
    hidden_inert = None
    hidden_fus = None
    
    for t in range(self.input_length):
        #print(segmentation.shape)
        seg = self.conv_seg(segmentation[:,t])
        #print(seg.shape)
        dep = self.conv_dep(depth[:,t])
        #print(dep.shape)
        mot = self.motion_fc(prev_motion[:,t])
        vis = torch.cat((seg, dep), dim=1)
        vis = torch.flatten(vis, start_dim=1)
        #print(vis.shape)
        if hidden_vis != None:
            output_vis, hidden_vis = self.vis_LSTM(vis, hidden_vis)
        else:
            output_vis, hidden_vis = self.vis_LSTM(vis)
        if hidden_inert != None:
            output_inert, hidden_inert = self.inertia_LSTM(mot, hidden_inert)
        else:
            output_inert, hidden_inert = self.inertia_LSTM(mot)
        combined = torch.cat((output_vis, output_inert), dim=1)
        if hidden_fus != None:
            _, hidden_fus = self.fusion_LSTM(combined, hidden_fus)
        else:
            _, hidden_fus = self.fusion_LSTM(combined)

    #print("Prev motion: " + str(prev_motion.shape))
    de_mot = prev_motion[:,-1]
    output_tensor = torch.zeros(self.sequence_length, self.batch_size, 4).to(segmentation.device)
    for t in range(self.sequence_length):
        #print(de_mot.shape)
        de_mot = self.de_motion_fc(de_mot)
        de_output_inert, hidden_inert = self.de_inertia_LSTM(de_mot, hidden_inert)
        de_output_vis, hidden_vis = self.de_vis_LSTM(torch.zeros(self.batch_size, 32).to(segmentation.device), hidden_vis)
        #print(de_output_vis.shape, de_output_inert.shape)
        combined = torch.cat((de_output_vis, de_output_inert), dim=1)
        de_output_fus, hidden_fus = self.de_fusion_LSTM(combined, hidden_fus)
        #print("de_output_fus: " + str(de_output_fus.shape))
        output_t = self.output_fc(de_output_fus)
        #print("output_t: " + str(output_t.shape))
        #output_t = output_t.unsqueeze(0)
        de_mot = output_t
        output_tensor[t] = output_t.unsqueeze(0)
        
    return output_tensor

# %%
torch.cuda.empty_cache()
batch_size = 256
learning_rate = 1e-3
num_epochs = 10
input_window = 5
prediction_window = 10
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("cuda" if torch.cuda.is_available() else "cpu")
model = NeuralNetwork(batch_size, input_window, prediction_window, device=device).to(device)

train_dataset = DoomMotionDataset(coco_train, TRAIN_RUN, input_window, prediction_window)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

val_dataset = DoomMotionDataset(coco_val, VAL_RUN, input_window, prediction_window)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Loss function and optimizer
criterion = torch.nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", unit="batch")
    for batch_idx, batch in enumerate(progress_bar):
        prev_motion, next_motion, previous_seg, previous_dep = batch["prev_motion"], batch["next_motion"], batch["previous_seg"], batch["previous_dep"]
        prev_motion, next_motion, previous_seg, previous_dep = prev_motion.to(device), next_motion.to(device), previous_seg.to(device), previous_dep.to(device)

        if prev_motion.shape[0] != next_motion.shape[0]:
                continue

        optimizer.zero_grad()

        outputs = model(previous_seg, previous_dep, prev_motion)
        outputs = outputs.permute(1, 0, 2)

        if outputs.size(0) != next_motion.size(0):
            continue
        
        loss = criterion(outputs, next_motion)
        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        progress_bar.set_postfix({
            "batch_loss": loss.item(),
            "batch_index": batch_idx + 1,
            "batch_size": prev_motion.size(0)
        })

    # Average loss per epoch
    epoch_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}")

    model.eval()  # Set the model to evaluation mode
    running_loss = 0.0
    
    
    progress_bar = tqdm(val_loader, desc="Validation", unit="batch")
    
    with torch.no_grad():  # Disable gradient calculations for evaluation
        for batch_idx, batch in enumerate(progress_bar):
            prev_motion, next_motion, previous_seg, previous_dep = batch["prev_motion"], batch["next_motion"], batch["previous_seg"], batch["previous_dep"]
            prev_motion, next_motion, previous_seg, previous_dep = prev_motion.to(device), next_motion.to(device), previous_seg.to(device), previous_dep.to(device)

            if prev_motion.shape[0] != next_motion.shape[0]:
                continue
                
            outputs = model(previous_seg, previous_dep, prev_motion)
            outputs = outputs.permute(1, 0, 2)

            if outputs.size(0) != next_motion.size(0):
                continue
            
            loss = criterion(outputs, next_motion)
            
            running_loss += loss.item()
            
            progress_bar.set_postfix({
                "batch_loss": loss.item(),
                "batch_index": batch_idx + 1,
                "batch_size": prev_motion.size(0)
            })
    
    # Average loss over all batches
    val_loss = running_loss / len(val_loader)
    print(f"Val Loss: {val_loss:.4f}")

# Save the trained model
torch.save(model.state_dict(), "multimodal_seq2seq.pth")
# Out:
# cuda
# /tmp/ipykernel_3275170/2893372662.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   depth_mask = torch.tensor(depth_mask, dtype=torch.float32)
# run1/map01/rgb/000002.png
# run1/map01/rgb/000003.png
# run1/map01/rgb/000004.png
# run1/map01/rgb/000005.png
# run1/map01/rgb/000006.png
# run1/map01/rgb/000007.png
# run1/map01/rgb/000008.png
# run1/map01/rgb/000009.png
# run1/map01/rgb/000010.png
# run1/map01/rgb/000011.png
# run1/map01/rgb/000012.png
# run1/map01/rgb/000013.png
# run1/map01/rgb/000014.png
# run1/map01/rgb/000015.png
# run1/map01/rgb/000016.png
# run1/map01/rgb/000017.png
# run1/map01/rgb/000018.png
# run1/map01/rgb/000019.png
# run1/map01/rgb/000020.png
# run1/map01/rgb/000021.png
# run1/map01/rgb/000022.png
# run1/map01/rgb/000023.png
# run1/map01/rgb/000024.png
# run1/map01/rgb/000025.png
# run1/map01/rgb/000026.png
# run1/map01/rgb/000027.png
# run1/map01/rgb/000028.png
# run1/map01/rgb/000029.png
# run1/map01/rgb/000030.png
# run1/map01/rgb/000031.png
# run1/map01/rgb/000032.png
# run1/map01/rgb/000033.png
# run1/map01/rgb/000034.png
# run1/map01/rgb/000035.png
# run1/map01/rgb/000036.png
# run1/map01/rgb/000037.png
# run1/map01/rgb/000038.png
# run1/map01/rgb/000039.png
# run1/map01/rgb/000040.png
# run1/map01/rgb/000041.png
# run1/map01/rgb/000042.png
# run1/map01/rgb/000043.png
# run1/map01/rgb/000044.png
# run1/map01/rgb/000045.png
# run1/map01/rgb/000046.png
# run1/map01/rgb/000047.png
# run1/map01/rgb/000048.png
# run1/map01/rgb/000049.png
# run1/map01/rgb/000050.png
# run1/map01/rgb/000051.png
# run1/map01/rgb/000052.png
# run1/map01/rgb/000053.png
# run1/map01/rgb/000054.png
# run1/map01/rgb/000055.png
# run1/map01/rgb/000056.png
# run1/map01/rgb/000057.png
# run1/map01/rgb/000058.png
# run1/map01/rgb/000059.png
# run1/map01/rgb/000060.png
# run1/map01/rgb/000061.png
# run1/map01/rgb/000062.png
# run1/map01/rgb/000063.png
# run1/map01/rgb/000064.png
# run1/map01/rgb/000065.png
# run1/map01/rgb/000066.png
# run1/map01/rgb/000067.png
# run1/map01/rgb/000068.png
# run1/map01/rgb/000069.png
# run1/map01/rgb/000070.png
# run1/map01/rgb/000071.png
# run1/map01/rgb/000072.png
# run1/map01/rgb/000073.png
# run1/map01/rgb/000074.png
# run1/map01/rgb/000075.png
# run1/map01/rgb/000076.png
# run1/map01/rgb/000077.png
# run1/map01/rgb/000078.png
# run1/map01/rgb/000079.png
# run1/map01/rgb/000080.png
# run1/map01/rgb/000081.png
# run1/map01/rgb/000082.png
# run1/map01/rgb/000083.png
# run1/map01/rgb/000084.png
# run1/map01/rgb/000085.png
# run1/map01/rgb/000086.png
# run1/map01/rgb/000087.png
# run1/map01/rgb/000088.png
# run1/map01/rgb/000089.png
# run1/map01/rgb/000090.png
# run1/map01/rgb/000091.png
# run1/map01/rgb/000092.png
# run1/map01/rgb/000093.png
# run1/map01/rgb/000094.png
# run1/map01/rgb/000095.png
# run1/map01/rgb/000096.png
# run1/map01/rgb/000097.png
# run1/map01/rgb/000098.png
# run1/map01/rgb/000099.png
# run1/map01/rgb/000100.png
# run1/map01/rgb/000101.png
# run1/map01/rgb/000102.png
# run1/map01/rgb/000103.png
# run1/map01/rgb/000104.png
# run1/map01/rgb/000105.png
# run1/map01/rgb/000106.png
# run1/map01/rgb/000107.png
# run1/map01/rgb/000108.png
# run1/map01/rgb/000109.png
# run1/map01/rgb/000110.png
# run1/map01/rgb/000111.png
# run1/map01/rgb/000112.png
# run1/map01/rgb/000113.png
# run1/map01/rgb/000114.png
# run1/map01/rgb/000115.png
# run1/map01/rgb/000116.png
# run1/map01/rgb/000117.png
# run1/map01/rgb/000118.png
# run1/map01/rgb/000119.png
# run1/map01/rgb/000120.png
# run1/map01/rgb/000121.png
# run1/map01/rgb/000122.png
# run1/map01/rgb/000123.png
# run1/map01/rgb/000124.png
# run1/map01/rgb/000125.png
# run1/map01/rgb/000126.png
# run1/map01/rgb/000127.png
# run1/map01/rgb/000128.png
# run1/map01/rgb/000129.png
# run1/map01/rgb/000130.png
# run1/map01/rgb/000131.png
# run1/map01/rgb/000132.png
# run1/map01/rgb/000133.png
# run1/map01/rgb/000134.png
# run1/map01/rgb/000135.png
# run1/map01/rgb/000136.png
# run1/map01/rgb/000137.png
# run1/map01/rgb/000138.png
# run1/map01/rgb/000139.png
# run1/map01/rgb/000140.png
# run1/map01/rgb/000141.png
# run1/map01/rgb/000142.png
# run1/map01/rgb/000143.png
# run1/map01/rgb/000144.png
# run1/map01/rgb/000145.png
# run1/map01/rgb/000146.png
# run1/map01/rgb/000147.png
# run1/map01/rgb/000148.png
# run1/map01/rgb/000149.png
# run1/map01/rgb/000150.png
# run1/map01/rgb/000151.png
# run1/map01/rgb/000152.png
# run1/map01/rgb/000153.png
# run1/map01/rgb/000154.png
# run1/map01/rgb/000155.png
# run1/map01/rgb/000156.png
# run1/map01/rgb/000157.png
# run1/map01/rgb/000158.png
# run1/map01/rgb/000159.png
# run1/map01/rgb/000160.png
# run1/map01/rgb/000161.png
# run1/map01/rgb/000162.png
# run1/map01/rgb/000163.png
# run1/map01/rgb/000164.png
# run1/map01/rgb/000165.png
# run1/map01/rgb/000166.png
# run1/map01/rgb/000167.png
# run1/map01/rgb/000168.png
# run1/map01/rgb/000169.png
# run1/map01/rgb/000170.png
# run1/map01/rgb/000171.png
# run1/map01/rgb/000172.png
# run1/map01/rgb/000173.png
# run1/map01/rgb/000174.png
# run1/map01/rgb/000175.png
# run1/map01/rgb/000176.png
# run1/map01/rgb/000177.png
# run1/map01/rgb/000178.png
# run1/map01/rgb/000179.png
# run1/map01/rgb/000180.png
# run1/map01/rgb/000181.png
# run1/map01/rgb/000182.png
# run1/map01/rgb/000183.png
# run1/map01/rgb/000184.png
# run1/map01/rgb/000185.png
# run1/map01/rgb/000186.png
# run1/map01/rgb/000187.png
# run1/map01/rgb/000188.png
# run1/map01/rgb/000189.png
# run1/map01/rgb/000190.png
# run1/map01/rgb/000191.png
# run1/map01/rgb/000192.png
# run1/map01/rgb/000193.png
# run1/map01/rgb/000194.png
# run1/map01/rgb/000195.png
# run1/map01/rgb/000196.png
# run1/map01/rgb/000197.png
# run1/map01/rgb/000198.png
# run1/map01/rgb/000199.png
# run1/map01/rgb/000200.png
# run1/map01/rgb/000201.png
# run1/map01/rgb/000202.png
# run1/map01/rgb/000203.png
# run1/map01/rgb/000204.png
# run1/map01/rgb/000205.png
# run1/map01/rgb/000206.png
# run1/map01/rgb/000207.png
# run1/map01/rgb/000208.png
# run1/map01/rgb/000209.png
# run1/map01/rgb/000210.png
# run1/map01/rgb/000211.png
# run1/map01/rgb/000212.png
# run1/map01/rgb/000213.png
# run1/map01/rgb/000214.png
# run1/map01/rgb/000215.png
# run1/map01/rgb/000216.png
# run1/map01/rgb/000217.png
# run1/map01/rgb/000218.png
# run1/map01/rgb/000219.png
# run1/map01/rgb/000220.png
# run1/map01/rgb/000221.png
# run1/map01/rgb/000222.png
# run1/map01/rgb/000223.png
# run1/map01/rgb/000224.png
# run1/map01/rgb/000225.png
# run1/map01/rgb/000226.png
# run1/map01/rgb/000227.png
# run1/map01/rgb/000228.png
# run1/map01/rgb/000229.png
# run1/map01/rgb/000230.png
# run1/map01/rgb/000231.png
# run1/map01/rgb/000232.png
# run1/map01/rgb/000233.png
# run1/map01/rgb/000234.png
# run1/map01/rgb/000235.png
# run1/map01/rgb/000236.png
# run1/map01/rgb/000237.png
# run1/map01/rgb/000238.png
# run1/map01/rgb/000239.png
# run1/map01/rgb/000240.png
# run1/map01/rgb/000241.png
# run1/map01/rgb/000242.png
# run1/map01/rgb/000243.png
# run1/map01/rgb/000244.png
# run1/map01/rgb/000245.png
# run1/map01/rgb/000246.png
# run1/map01/rgb/000247.png
# run1/map01/rgb/000248.png
# run1/map01/rgb/000249.png
# run1/map01/rgb/000250.png
# run1/map01/rgb/000251.png
# run1/map01/rgb/000252.png
# run1/map01/rgb/000253.png
# run1/map01/rgb/000254.png
# run1/map01/rgb/000255.png
# run1/map01/rgb/000256.png
# run1/map01/rgb/000257.png
# Epoch 1/10:   0%|                  | 1/991 [00:13<3:47:34, 13.79s/batch, batch_loss=32.6, batch_index=1, batch_size=256]
# run1/map01/rgb/000258.png
# run1/map01/rgb/000259.png
# run1/map01/rgb/000260.png
# run1/map01/rgb/000261.png
# run1/map01/rgb/000262.png
# run1/map01/rgb/000263.png
# run1/map01/rgb/000264.png
# run1/map01/rgb/000265.png
# run1/map01/rgb/000266.png
# run1/map01/rgb/000267.png
# run1/map01/rgb/000268.png
# run1/map01/rgb/000269.png
# run1/map01/rgb/000270.png
# run1/map01/rgb/000271.png
# run1/map01/rgb/000272.png
# run1/map01/rgb/000273.png
# run1/map01/rgb/000274.png
# run1/map01/rgb/000275.png
# run1/map01/rgb/000276.png
# run1/map01/rgb/000277.png
# run1/map01/rgb/000278.png
# run1/map01/rgb/000279.png
# run1/map01/rgb/000280.png
# run1/map01/rgb/000281.png
# run1/map01/rgb/000282.png
# run1/map01/rgb/000283.png
# run1/map01/rgb/000284.png
# run1/map01/rgb/000285.png
# run1/map01/rgb/000286.png
# run1/map01/rgb/000287.png
# run1/map01/rgb/000288.png
# run1/map01/rgb/000289.png
# run1/map01/rgb/000290.png
# run1/map01/rgb/000291.png
# run1/map01/rgb/000292.png
# run1/map01/rgb/000293.png
# run1/map01/rgb/000294.png
# run1/map01/rgb/000295.png
# run1/map01/rgb/000296.png
# run1/map01/rgb/000297.png
# run1/map01/rgb/000298.png
# run1/map01/rgb/000299.png
# run1/map01/rgb/000300.png
# run1/map01/rgb/000301.png
# run1/map01/rgb/000302.png
# run1/map01/rgb/000303.png
# run1/map01/rgb/000304.png
# run1/map01/rgb/000305.png
# run1/map01/rgb/000306.png
# run1/map01/rgb/000307.png
# run1/map01/rgb/000308.png
# run1/map01/rgb/000309.png
# run1/map01/rgb/000310.png
# run1/map01/rgb/000311.png
# run1/map01/rgb/000312.png
# run1/map01/rgb/000313.png
# run1/map01/rgb/000314.png
# run1/map01/rgb/000315.png
# run1/map01/rgb/000316.png
# run1/map01/rgb/000317.png
# run1/map01/rgb/000318.png
# run1/map01/rgb/000319.png
# run1/map01/rgb/000320.png
# run1/map01/rgb/000321.png
# run1/map01/rgb/000322.png
# run1/map01/rgb/000323.png
# run1/map01/rgb/000324.png
# run1/map01/rgb/000325.png
# run1/map01/rgb/000326.png
# run1/map01/rgb/000327.png
# run1/map01/rgb/000328.png
# run1/map01/rgb/000329.png
# run1/map01/rgb/000330.png
# run1/map01/rgb/000331.png
# run1/map01/rgb/000332.png
# run1/map01/rgb/000333.png
# run1/map01/rgb/000334.png
# run1/map01/rgb/000335.png
# run1/map01/rgb/000336.png
# run1/map01/rgb/000337.png
# run1/map01/rgb/000338.png
# run1/map01/rgb/000339.png
# run1/map01/rgb/000340.png
# run1/map01/rgb/000341.png
# run1/map01/rgb/000342.png
# run1/map01/rgb/000343.png
# run1/map01/rgb/000344.png
# run1/map01/rgb/000345.png
# run1/map01/rgb/000346.png
# run1/map01/rgb/000347.png
# run1/map01/rgb/000348.png
# run1/map01/rgb/000349.png
# run1/map01/rgb/000350.png
# run1/map01/rgb/000351.png
# run1/map01/rgb/000352.png
# run1/map01/rgb/000353.png
# run1/map01/rgb/000354.png
# run1/map01/rgb/000355.png
# run1/map01/rgb/000356.png
# run1/map01/rgb/000357.png
# run1/map01/rgb/000358.png
# run1/map01/rgb/000359.png
# run1/map01/rgb/000360.png
# run1/map01/rgb/000361.png
# run1/map01/rgb/000362.png
# run1/map01/rgb/000363.png
# run1/map01/rgb/000364.png
# run1/map01/rgb/000365.png
# run1/map01/rgb/000366.png
# run1/map01/rgb/000367.png
# run1/map01/rgb/000368.png
# run1/map01/rgb/000369.png
# run1/map01/rgb/000370.png
# run1/map01/rgb/000371.png
# run1/map01/rgb/000372.png
# run1/map01/rgb/000373.png
# run1/map01/rgb/000374.png
# run1/map01/rgb/000375.png
# run1/map01/rgb/000376.png
# run1/map01/rgb/000377.png
# run1/map01/rgb/000378.png
# run1/map01/rgb/000379.png
# run1/map01/rgb/000380.png
# run1/map01/rgb/000381.png
# run1/map01/rgb/000382.png
# run1/map01/rgb/000383.png
# run1/map01/rgb/000384.png
# run1/map01/rgb/000385.png
# run1/map01/rgb/000386.png
# run1/map01/rgb/000387.png
# run1/map01/rgb/000388.png
# run1/map01/rgb/000389.png
# run1/map01/rgb/000390.png
# run1/map01/rgb/000391.png
# run1/map01/rgb/000392.png
# run1/map01/rgb/000393.png
# run1/map01/rgb/000394.png
# run1/map01/rgb/000395.png
# run1/map01/rgb/000396.png
# run1/map01/rgb/000397.png
# run1/map01/rgb/000398.png
# run1/map01/rgb/000399.png
# run1/map01/rgb/000400.png
# run1/map01/rgb/000401.png
# run1/map01/rgb/000402.png
# run1/map01/rgb/000403.png
# run1/map01/rgb/000404.png
# run1/map01/rgb/000405.png
# run1/map01/rgb/000406.png
# run1/map01/rgb/000407.png
# run1/map01/rgb/000408.png
# run1/map01/rgb/000409.png
# run1/map01/rgb/000410.png
# run1/map01/rgb/000411.png
# run1/map01/rgb/000412.png
# run1/map01/rgb/000413.png
# run1/map01/rgb/000414.png
# run1/map01/rgb/000415.png
# run1/map01/rgb/000416.png
# run1/map01/rgb/000417.png
# run1/map01/rgb/000418.png
# run1/map01/rgb/000419.png
# run1/map01/rgb/000420.png
# run1/map01/rgb/000421.png
# run1/map01/rgb/000422.png
# run1/map01/rgb/000423.png
# run1/map01/rgb/000424.png
# run1/map01/rgb/000425.png
# run1/map01/rgb/000426.png
# run1/map01/rgb/000427.png
# run1/map01/rgb/000428.png
# run1/map01/rgb/000429.png
# run1/map01/rgb/000430.png
# run1/map01/rgb/000431.png
# run1/map01/rgb/000432.png
# run1/map01/rgb/000433.png
# run1/map01/rgb/000434.png
# run1/map01/rgb/000435.png
# run1/map01/rgb/000436.png
# run1/map01/rgb/000437.png
# run1/map01/rgb/000438.png
# run1/map01/rgb/000439.png
# run1/map01/rgb/000440.png
# run1/map01/rgb/000441.png
# run1/map01/rgb/000442.png
# run1/map01/rgb/000443.png
# run1/map01/rgb/000444.png
# run1/map01/rgb/000445.png
# run1/map01/rgb/000446.png
# run1/map01/rgb/000447.png
# run1/map01/rgb/000448.png
# run1/map01/rgb/000449.png
# run1/map01/rgb/000450.png
# run1/map01/rgb/000451.png
# run1/map01/rgb/000452.png
# run1/map01/rgb/000453.png
# run1/map01/rgb/000454.png
# run1/map01/rgb/000455.png
# run1/map01/rgb/000456.png
# run1/map01/rgb/000457.png
# run1/map01/rgb/000458.png
# run1/map01/rgb/000459.png
# run1/map01/rgb/000460.png
# run1/map01/rgb/000461.png
# run1/map01/rgb/000462.png
# run1/map01/rgb/000463.png
# run1/map01/rgb/000464.png
# run1/map01/rgb/000465.png
# run1/map01/rgb/000466.png
# run1/map01/rgb/000467.png
# run1/map01/rgb/000468.png
# run1/map01/rgb/000469.png
# run1/map01/rgb/000470.png
# run1/map01/rgb/000471.png
# run1/map01/rgb/000472.png
# run1/map01/rgb/000473.png
# run1/map01/rgb/000474.png
# run1/map01/rgb/000475.png
# run1/map01/rgb/000476.png
# run1/map01/rgb/000477.png
# run1/map01/rgb/000478.png
# run1/map01/rgb/000479.png
# run1/map01/rgb/000480.png
# run1/map01/rgb/000481.png
# run1/map01/rgb/000482.png
# run1/map01/rgb/000483.png
# run1/map01/rgb/000484.png
# run1/map01/rgb/000485.png
# run1/map01/rgb/000486.png
# run1/map01/rgb/000487.png
# run1/map01/rgb/000488.png
# run1/map01/rgb/000489.png
# run1/map01/rgb/000490.png
# run1/map01/rgb/000491.png
# run1/map01/rgb/000492.png
# run1/map01/rgb/000493.png
# run1/map01/rgb/000494.png
# run1/map01/rgb/000495.png
# run1/map01/rgb/000496.png
# run1/map01/rgb/000497.png
# run1/map01/rgb/000498.png
# run1/map01/rgb/000499.png
# run1/map01/rgb/000500.png
# run1/map01/rgb/000501.png
# run1/map01/rgb/000502.png
# run1/map01/rgb/000503.png
# run1/map01/rgb/000504.png
# run1/map01/rgb/000505.png
# run1/map01/rgb/000506.png
# run1/map01/rgb/000507.png
# run1/map01/rgb/000508.png
# run1/map01/rgb/000509.png
# run1/map01/rgb/000510.png
# run1/map01/rgb/000511.png
# run1/map01/rgb/000512.png
# run1/map01/rgb/000513.png
# Epoch 1/10:   0%|                  | 2/991 [00:27<3:47:42, 13.81s/batch, batch_loss=32.5, batch_index=2, batch_size=256]
# run1/map01/rgb/000514.png
# run1/map01/rgb/000515.png
# run1/map01/rgb/000516.png
# run1/map01/rgb/000517.png
# run1/map01/rgb/000518.png
# run1/map01/rgb/000519.png
# run1/map01/rgb/000520.png
# run1/map01/rgb/000521.png
# run1/map01/rgb/000522.png
# run1/map01/rgb/000523.png
# run1/map01/rgb/000524.png
# run1/map01/rgb/000525.png
# run1/map01/rgb/000526.png
# run1/map01/rgb/000527.png
# run1/map01/rgb/000528.png
# run1/map01/rgb/000529.png
# run1/map01/rgb/000530.png
# run1/map01/rgb/000531.png
# run1/map01/rgb/000532.png
# run1/map01/rgb/000533.png
# run1/map01/rgb/000534.png
# run1/map01/rgb/000535.png
# run1/map01/rgb/000536.png
# run1/map01/rgb/000537.png
# run1/map01/rgb/000538.png
# run1/map01/rgb/000539.png
# run1/map01/rgb/000540.png
# run1/map01/rgb/000541.png
# run1/map01/rgb/000542.png
# run1/map01/rgb/000543.png
# run1/map01/rgb/000544.png
# run1/map01/rgb/000545.png
# run1/map01/rgb/000546.png
# run1/map01/rgb/000547.png
# run1/map01/rgb/000548.png
# run1/map01/rgb/000549.png
# run1/map01/rgb/000550.png
# run1/map01/rgb/000551.png
# run1/map01/rgb/000552.png
# run1/map01/rgb/000553.png
# run1/map01/rgb/000554.png
# run1/map01/rgb/000555.png
# run1/map01/rgb/000556.png
# run1/map01/rgb/000557.png
# run1/map01/rgb/000558.png
# run1/map01/rgb/000559.png
# run1/map01/rgb/000560.png
# run1/map01/rgb/000561.png
# run1/map01/rgb/000562.png
# run1/map01/rgb/000563.png
# run1/map01/rgb/000564.png
# run1/map01/rgb/000565.png
# run1/map01/rgb/000566.png
# run1/map01/rgb/000567.png
# run1/map01/rgb/000568.png
# run1/map01/rgb/000569.png
# run1/map01/rgb/000570.png
# run1/map01/rgb/000571.png
# run1/map01/rgb/000572.png
# run1/map01/rgb/000573.png
# run1/map01/rgb/000574.png
# run1/map01/rgb/000575.png
# run1/map01/rgb/000576.png
# run1/map01/rgb/000577.png
# run1/map01/rgb/000578.png
# run1/map01/rgb/000579.png
# run1/map01/rgb/000580.png
# run1/map01/rgb/000581.png
# run1/map01/rgb/000582.png
# run1/map01/rgb/000583.png
# run1/map01/rgb/000584.png
# run1/map01/rgb/000585.png
# run1/map01/rgb/000586.png
# run1/map01/rgb/000587.png
# run1/map01/rgb/000588.png
# run1/map01/rgb/000589.png
# run1/map01/rgb/000590.png
# run1/map01/rgb/000591.png
# run1/map01/rgb/000592.png
# run1/map01/rgb/000593.png
# run1/map01/rgb/000594.png
# run1/map01/rgb/000595.png
# run1/map01/rgb/000596.png
# run1/map01/rgb/000597.png
# run1/map01/rgb/000598.png
# run1/map01/rgb/000599.png
# run1/map01/rgb/000600.png
# run1/map01/rgb/000601.png
# run1/map01/rgb/000602.png
# run1/map01/rgb/000603.png
# run1/map01/rgb/000604.png
# run1/map01/rgb/000605.png
# run1/map01/rgb/000606.png
# run1/map01/rgb/000607.png
# run1/map01/rgb/000608.png
# run1/map01/rgb/000609.png
# run1/map01/rgb/000610.png
# run1/map01/rgb/000611.png
# run1/map01/rgb/000612.png
# run1/map01/rgb/000613.png
# run1/map01/rgb/000614.png
# run1/map01/rgb/000615.png
# run1/map01/rgb/000616.png
# run1/map01/rgb/000617.png
# run1/map01/rgb/000618.png
# run1/map01/rgb/000619.png
# run1/map01/rgb/000620.png
# run1/map01/rgb/000621.png
# run1/map01/rgb/000622.png
# run1/map01/rgb/000623.png
# run1/map01/rgb/000624.png
# run1/map01/rgb/000625.png
# run1/map01/rgb/000626.png
# run1/map01/rgb/000627.png
# run1/map01/rgb/000628.png
# run1/map01/rgb/000629.png
# run1/map01/rgb/000630.png
# run1/map01/rgb/000631.png
# run1/map01/rgb/000632.png
# run1/map01/rgb/000633.png
# run1/map01/rgb/000634.png
# run1/map01/rgb/000635.png
# run1/map01/rgb/000636.png
# run1/map01/rgb/000637.png
# run1/map01/rgb/000638.png
# run1/map01/rgb/000639.png
# run1/map01/rgb/000640.png
# run1/map01/rgb/000641.png
# run1/map01/rgb/000642.png
# run1/map01/rgb/000643.png
# run1/map01/rgb/000644.png
# run1/map01/rgb/000645.png
# run1/map01/rgb/000646.png
# run1/map01/rgb/000647.png
# run1/map01/rgb/000648.png
# run1/map01/rgb/000649.png
# run1/map01/rgb/000650.png
# run1/map01/rgb/000651.png
# run1/map01/rgb/000652.png
# run1/map01/rgb/000653.png
# run1/map01/rgb/000654.png
# run1/map01/rgb/000655.png
# run1/map01/rgb/000656.png
# run1/map01/rgb/000657.png
# run1/map01/rgb/000658.png
# run1/map01/rgb/000659.png
# run1/map01/rgb/000660.png
# run1/map01/rgb/000661.png
# run1/map01/rgb/000662.png
# run1/map01/rgb/000663.png
# run1/map01/rgb/000664.png
# run1/map01/rgb/000665.png
# run1/map01/rgb/000666.png
# run1/map01/rgb/000667.png
# run1/map01/rgb/000668.png
# run1/map01/rgb/000669.png
# run1/map01/rgb/000670.png
# run1/map01/rgb/000671.png
# run1/map01/rgb/000672.png
# run1/map01/rgb/000673.png
# run1/map01/rgb/000674.png
# run1/map01/rgb/000675.png
# run1/map01/rgb/000676.png
# run1/map01/rgb/000677.png
# run1/map01/rgb/000678.png
# run1/map01/rgb/000679.png
# run1/map01/rgb/000680.png
# run1/map01/rgb/000681.png
# run1/map01/rgb/000682.png
# run1/map01/rgb/000683.png
# run1/map01/rgb/000684.png
# run1/map01/rgb/000685.png
# run1/map01/rgb/000686.png
# run1/map01/rgb/000687.png
# run1/map01/rgb/000688.png
# run1/map01/rgb/000689.png
# run1/map01/rgb/000690.png
# run1/map01/rgb/000691.png
# run1/map01/rgb/000692.png
# run1/map01/rgb/000693.png
# run1/map01/rgb/000694.png
# run1/map01/rgb/000695.png
# run1/map01/rgb/000696.png
# run1/map01/rgb/000697.png
# run1/map01/rgb/000698.png
# run1/map01/rgb/000699.png
# run1/map01/rgb/000700.png
# run1/map01/rgb/000701.png
# run1/map01/rgb/000702.png
# run1/map01/rgb/000703.png
# run1/map01/rgb/000704.png
# run1/map01/rgb/000705.png
# run1/map01/rgb/000706.png
# run1/map01/rgb/000707.png
# run1/map01/rgb/000708.png
# run1/map01/rgb/000709.png
# run1/map01/rgb/000710.png
# run1/map01/rgb/000711.png
# run1/map01/rgb/000712.png
# run1/map01/rgb/000713.png
# run1/map01/rgb/000714.png
# run1/map01/rgb/000715.png
# run1/map01/rgb/000716.png
# run1/map01/rgb/000717.png
# run1/map01/rgb/000718.png
# run1/map01/rgb/000719.png
# run1/map01/rgb/000720.png
# run1/map01/rgb/000721.png
# run1/map01/rgb/000722.png
# run1/map01/rgb/000723.png
# run1/map01/rgb/000724.png
# run1/map01/rgb/000725.png
# run1/map01/rgb/000726.png
# run1/map01/rgb/000727.png
# run1/map01/rgb/000728.png
# run1/map01/rgb/000729.png
# run1/map01/rgb/000730.png
# run1/map01/rgb/000731.png
# run1/map01/rgb/000732.png
# run1/map01/rgb/000733.png
# run1/map01/rgb/000734.png
# run1/map01/rgb/000735.png
# run1/map01/rgb/000736.png
# run1/map01/rgb/000737.png
# run1/map01/rgb/000738.png
# run1/map01/rgb/000739.png
# run1/map01/rgb/000740.png
# run1/map01/rgb/000741.png
# run1/map01/rgb/000742.png
# run1/map01/rgb/000743.png
# run1/map01/rgb/000744.png
# run1/map01/rgb/000745.png
# run1/map01/rgb/000746.png
# run1/map01/rgb/000747.png
# run1/map01/rgb/000748.png
# run1/map01/rgb/000749.png
# run1/map01/rgb/000750.png
# run1/map01/rgb/000751.png
# run1/map01/rgb/000752.png
# run1/map01/rgb/000753.png
# run1/map01/rgb/000754.png
# run1/map01/rgb/000755.png
# run1/map01/rgb/000756.png
# run1/map01/rgb/000757.png
# run1/map01/rgb/000758.png
# run1/map01/rgb/000759.png
# run1/map01/rgb/000760.png
# run1/map01/rgb/000761.png
# run1/map01/rgb/000762.png
# run1/map01/rgb/000763.png
# run1/map01/rgb/000764.png
# run1/map01/rgb/000765.png
# run1/map01/rgb/000766.png
# run1/map01/rgb/000767.png
# run1/map01/rgb/000768.png
# run1/map01/rgb/000769.png
# Epoch 1/10:   0%|                    | 3/991 [00:41<3:48:47, 13.89s/batch, batch_loss=27, batch_index=3, batch_size=256]
# run1/map01/rgb/000770.png
# run1/map01/rgb/000771.png
# run1/map01/rgb/000772.png
# run1/map01/rgb/000773.png
# run1/map01/rgb/000774.png
# run1/map01/rgb/000775.png
# run1/map01/rgb/000776.png
# run1/map01/rgb/000777.png
# run1/map01/rgb/000778.png
# run1/map01/rgb/000779.png
# run1/map01/rgb/000780.png
# run1/map01/rgb/000781.png
# run1/map01/rgb/000782.png
# run1/map01/rgb/000783.png
# run1/map01/rgb/000784.png
# run1/map01/rgb/000785.png
# run1/map01/rgb/000786.png
# run1/map01/rgb/000787.png
# run1/map01/rgb/000788.png
# run1/map01/rgb/000789.png
# run1/map01/rgb/000790.png
# run1/map01/rgb/000791.png
# run1/map01/rgb/000792.png
# run1/map01/rgb/000793.png
# run1/map01/rgb/000794.png
# run1/map01/rgb/000795.png
# run1/map01/rgb/000796.png
# run1/map01/rgb/000797.png
# run1/map01/rgb/000798.png
# run1/map01/rgb/000799.png
# run1/map01/rgb/000800.png
# run1/map01/rgb/000801.png
# run1/map01/rgb/000802.png
# run1/map01/rgb/000803.png
# run1/map01/rgb/000804.png
# run1/map01/rgb/000805.png
# run1/map01/rgb/000806.png
# run1/map01/rgb/000807.png
# run1/map01/rgb/000808.png
# run1/map01/rgb/000809.png
# run1/map01/rgb/000810.png
# run1/map01/rgb/000811.png
# run1/map01/rgb/000812.png
# run1/map01/rgb/000813.png
# run1/map01/rgb/000814.png
# run1/map01/rgb/000815.png
# run1/map01/rgb/000816.png
# run1/map01/rgb/000817.png
# run1/map01/rgb/000818.png
# run1/map01/rgb/000819.png
# run1/map01/rgb/000820.png
# run1/map01/rgb/000821.png
# run1/map01/rgb/000822.png
# run1/map01/rgb/000823.png
# run1/map01/rgb/000824.png
# run1/map01/rgb/000825.png
# run1/map01/rgb/000826.png
# run1/map01/rgb/000827.png
# run1/map01/rgb/000828.png
# run1/map01/rgb/000829.png
# run1/map01/rgb/000830.png
# run1/map01/rgb/000831.png
# run1/map01/rgb/000832.png
# run1/map01/rgb/000833.png
# run1/map01/rgb/000834.png
# run1/map01/rgb/000835.png
# run1/map01/rgb/000836.png
# run1/map01/rgb/000837.png
# run1/map01/rgb/000838.png
# run1/map01/rgb/000839.png
# run1/map01/rgb/000840.png
# run1/map01/rgb/000841.png
# run1/map01/rgb/000842.png
# run1/map01/rgb/000843.png
# run1/map01/rgb/000844.png
# run1/map01/rgb/000845.png
# run1/map01/rgb/000846.png
# run1/map01/rgb/000847.png
# run1/map01/rgb/000848.png
# run1/map01/rgb/000849.png
# run1/map01/rgb/000850.png
# run1/map01/rgb/000851.png
# run1/map01/rgb/000852.png
# run1/map01/rgb/000853.png
# run1/map01/rgb/000854.png
# run1/map01/rgb/000855.png
# run1/map01/rgb/000856.png
# run1/map01/rgb/000857.png
# run1/map01/rgb/000858.png
# run1/map01/rgb/000859.png
# run1/map01/rgb/000860.png
# run1/map01/rgb/000861.png
# run1/map01/rgb/000862.png
# run1/map01/rgb/000863.png
# run1/map01/rgb/000864.png
# run1/map01/rgb/000865.png
# run1/map01/rgb/000866.png
# run1/map01/rgb/000867.png
# run1/map01/rgb/000868.png
# run1/map01/rgb/000869.png
# run1/map01/rgb/000870.png
# run1/map01/rgb/000871.png
# run1/map01/rgb/000872.png
# run1/map01/rgb/000873.png
# run1/map01/rgb/000874.png
# run1/map01/rgb/000875.png
# run1/map01/rgb/000876.png
# run1/map01/rgb/000877.png
# run1/map01/rgb/000878.png
# run1/map01/rgb/000879.png
# run1/map01/rgb/000880.png
# run1/map01/rgb/000881.png
# run1/map01/rgb/000882.png
# run1/map01/rgb/000883.png
# run1/map01/rgb/000884.png
# run1/map01/rgb/000885.png
# run1/map01/rgb/000886.png
# run1/map01/rgb/000887.png
# run1/map01/rgb/000888.png
# run1/map01/rgb/000889.png
# run1/map01/rgb/000890.png
# run1/map01/rgb/000891.png
# run1/map01/rgb/000892.png
# run1/map01/rgb/000893.png
# run1/map01/rgb/000894.png
# run1/map01/rgb/000895.png
# run1/map01/rgb/000896.png
# run1/map01/rgb/000897.png
# run1/map01/rgb/000898.png
# run1/map01/rgb/000899.png
# run1/map01/rgb/000900.png
# run1/map01/rgb/000901.png
# run1/map01/rgb/000902.png
# run1/map01/rgb/000903.png
# run1/map01/rgb/000904.png
# run1/map01/rgb/000905.png
# run1/map01/rgb/000906.png
# run1/map01/rgb/000907.png
# run1/map01/rgb/000908.png
# run1/map01/rgb/000909.png
# run1/map01/rgb/000910.png
# run1/map01/rgb/000911.png
# run1/map01/rgb/000912.png
# run1/map01/rgb/000913.png
# run1/map01/rgb/000914.png
# run1/map01/rgb/000915.png
# run1/map01/rgb/000916.png
# run1/map01/rgb/000917.png
# run1/map01/rgb/000918.png
# run1/map01/rgb/000919.png
# run1/map01/rgb/000920.png
# run1/map01/rgb/000921.png
# run1/map01/rgb/000922.png
# run1/map01/rgb/000923.png
# run1/map01/rgb/000924.png
# run1/map01/rgb/000925.png
# run1/map01/rgb/000926.png
# run1/map01/rgb/000927.png
# run1/map01/rgb/000928.png
# run1/map01/rgb/000929.png
# run1/map01/rgb/000930.png
# run1/map01/rgb/000931.png
# run1/map01/rgb/000932.png
# run1/map01/rgb/000933.png
# run1/map01/rgb/000934.png
# run1/map01/rgb/000935.png
# run1/map01/rgb/000936.png
# run1/map01/rgb/000937.png
# run1/map01/rgb/000938.png
# run1/map01/rgb/000939.png
# run1/map01/rgb/000940.png
# run1/map01/rgb/000941.png
# run1/map01/rgb/000942.png
# run1/map01/rgb/000943.png
# run1/map01/rgb/000944.png
# run1/map01/rgb/000945.png
# run1/map01/rgb/000946.png
# run1/map01/rgb/000947.png
# run1/map01/rgb/000948.png
# run1/map01/rgb/000949.png
# run1/map01/rgb/000950.png
# run1/map01/rgb/000951.png
# run1/map01/rgb/000952.png
# run1/map01/rgb/000953.png
# run1/map01/rgb/000954.png
# run1/map01/rgb/000955.png
# run1/map01/rgb/000956.png
# run1/map01/rgb/000957.png
# run1/map01/rgb/000958.png
# run1/map01/rgb/000959.png
# run1/map01/rgb/000960.png
# run1/map01/rgb/000961.png
# run1/map01/rgb/000962.png
# run1/map01/rgb/000963.png
# run1/map01/rgb/000964.png
# run1/map01/rgb/000965.png
# run1/map01/rgb/000966.png
# run1/map01/rgb/000967.png
# run1/map01/rgb/000968.png
# run1/map01/rgb/000969.png
# run1/map01/rgb/000970.png
# run1/map01/rgb/000971.png
# run1/map01/rgb/000972.png
# run1/map01/rgb/000973.png
# run1/map01/rgb/000974.png
# run1/map01/rgb/000975.png
# run1/map01/rgb/000976.png
# run1/map01/rgb/000977.png
# run1/map01/rgb/000978.png
# run1/map01/rgb/000979.png
# run1/map01/rgb/000980.png
# run1/map01/rgb/000981.png
# run1/map01/rgb/000982.png
# run1/map01/rgb/000983.png
# run1/map01/rgb/000984.png
# run1/map01/rgb/000985.png
# run1/map01/rgb/000986.png
# run1/map01/rgb/000987.png
# run1/map01/rgb/000988.png
# run1/map01/rgb/000989.png
# run1/map01/rgb/000990.png
# run1/map01/rgb/000991.png
# run1/map01/rgb/000992.png
# run1/map01/rgb/000993.png
# run1/map01/rgb/000994.png
# run1/map01/rgb/000995.png
# run1/map01/rgb/000996.png
# run1/map01/rgb/000997.png
# run1/map01/rgb/000998.png
# run1/map01/rgb/000999.png
# run1/map01/rgb/001000.png
# run1/map01/rgb/001001.png
# run1/map01/rgb/001002.png
# run1/map01/rgb/001003.png
# run1/map01/rgb/001004.png
# run1/map01/rgb/001005.png
# run1/map01/rgb/001006.png
# run1/map01/rgb/001007.png
# run1/map01/rgb/001008.png
# run1/map01/rgb/001009.png
# run1/map01/rgb/001010.png
# run1/map01/rgb/001011.png
# run1/map01/rgb/001012.png
# run1/map01/rgb/001013.png
# run1/map01/rgb/001014.png
# run1/map01/rgb/001015.png
# run1/map01/rgb/001016.png
# run1/map01/rgb/001017.png
# run1/map01/rgb/001018.png
# run1/map01/rgb/001019.png
# run1/map01/rgb/001020.png
# run1/map01/rgb/001021.png
# run1/map01/rgb/001022.png
# run1/map01/rgb/001023.png
# run1/map01/rgb/001024.png
# run1/map01/rgb/001025.png
# Epoch 1/10:   0%|                  | 4/991 [00:55<3:47:31, 13.83s/batch, batch_loss=12.4, batch_index=4, batch_size=256]
# run1/map01/rgb/001026.png
# run1/map01/rgb/001027.png
# run1/map01/rgb/001028.png
# run1/map01/rgb/001029.png
# run1/map01/rgb/001030.png
# run1/map01/rgb/001031.png
# run1/map01/rgb/001032.png
# run1/map01/rgb/001033.png
# run1/map01/rgb/001034.png
# run1/map01/rgb/001035.png
# run1/map01/rgb/001036.png
# run1/map01/rgb/001037.png
# run1/map01/rgb/001038.png
# run1/map01/rgb/001039.png
# run1/map01/rgb/001040.png
# run1/map01/rgb/001041.png
# run1/map01/rgb/001042.png
# run1/map01/rgb/001043.png
# run1/map01/rgb/001044.png
# run1/map01/rgb/001045.png
# run1/map01/rgb/001046.png
# run1/map01/rgb/001047.png
# run1/map01/rgb/001048.png
# run1/map01/rgb/001049.png
# run1/map01/rgb/001050.png
# run1/map01/rgb/001051.png
# run1/map01/rgb/001052.png
# run1/map01/rgb/001053.png
# run1/map01/rgb/001054.png
# run1/map01/rgb/001055.png
# run1/map01/rgb/001056.png
# run1/map01/rgb/001057.png
# run1/map01/rgb/001058.png
# run1/map01/rgb/001059.png
# run1/map01/rgb/001060.png
# run1/map01/rgb/001061.png
# run1/map01/rgb/001062.png
# run1/map01/rgb/001063.png
# run1/map01/rgb/001064.png
# run1/map01/rgb/001065.png
# run1/map01/rgb/001066.png
# run1/map01/rgb/001067.png
# run1/map01/rgb/001068.png
# run1/map01/rgb/001069.png
# run1/map01/rgb/001070.png
# run1/map01/rgb/001071.png
# run1/map01/rgb/001072.png
# run1/map01/rgb/001073.png
# run1/map01/rgb/001074.png
# run1/map01/rgb/001075.png
# run1/map01/rgb/001076.png
# run1/map01/rgb/001077.png
# run1/map01/rgb/001078.png
# run1/map01/rgb/001079.png
# run1/map01/rgb/001080.png
# run1/map01/rgb/001081.png
# run1/map01/rgb/001082.png
# run1/map01/rgb/001083.png
# run1/map01/rgb/001084.png
# run1/map01/rgb/001085.png
# run1/map01/rgb/001086.png
# run1/map01/rgb/001087.png
# run1/map01/rgb/001088.png
# run1/map01/rgb/001089.png
# run1/map01/rgb/001090.png
# run1/map01/rgb/001091.png
# run1/map01/rgb/001092.png
# run1/map01/rgb/001093.png
# run1/map01/rgb/001094.png
# run1/map01/rgb/001095.png
# run1/map01/rgb/001096.png
# run1/map01/rgb/001097.png
# run1/map01/rgb/001098.png
# run1/map01/rgb/001099.png
# run1/map01/rgb/001100.png
# run1/map01/rgb/001101.png
# run1/map01/rgb/001102.png
# run1/map01/rgb/001103.png
# run1/map01/rgb/001104.png
# run1/map01/rgb/001105.png
# run1/map01/rgb/001106.png
# run1/map01/rgb/001107.png
# run1/map01/rgb/001108.png
# run1/map01/rgb/001109.png
# run1/map01/rgb/001110.png
# run1/map01/rgb/001111.png
# run1/map01/rgb/001112.png
# run1/map01/rgb/001113.png
# run1/map01/rgb/001114.png
# run1/map01/rgb/001115.png
# run1/map01/rgb/001116.png
# run1/map01/rgb/001117.png
# run1/map01/rgb/001118.png
# run1/map01/rgb/001119.png
# run1/map01/rgb/001120.png
# run1/map01/rgb/001121.png
# run1/map01/rgb/001122.png
# run1/map01/rgb/001123.png
# run1/map01/rgb/001124.png
# run1/map01/rgb/001125.png
# run1/map01/rgb/001126.png
# run1/map01/rgb/001127.png
# run1/map01/rgb/001128.png
# run1/map01/rgb/001129.png
# run1/map01/rgb/001130.png
# run1/map01/rgb/001131.png
# run1/map01/rgb/001132.png
# run1/map01/rgb/001133.png
# run1/map01/rgb/001134.png
# run1/map01/rgb/001135.png
# run1/map01/rgb/001136.png
# run1/map01/rgb/001137.png
# run1/map01/rgb/001138.png
# run1/map01/rgb/001139.png
# run1/map01/rgb/001140.png
# run1/map01/rgb/001141.png
# run1/map01/rgb/001142.png
# run1/map01/rgb/001143.png
# run1/map01/rgb/001144.png
# run1/map01/rgb/001145.png
# run1/map01/rgb/001146.png
# run1/map01/rgb/001147.png
# run1/map01/rgb/001148.png
# run1/map01/rgb/001149.png
# run1/map01/rgb/001150.png
# run1/map01/rgb/001151.png
# run1/map01/rgb/001152.png
# run1/map01/rgb/001153.png
# run1/map01/rgb/001154.png
# run1/map01/rgb/001155.png
# run1/map01/rgb/001156.png
# run1/map01/rgb/001157.png
# run1/map01/rgb/001158.png
# run1/map01/rgb/001159.png
# run1/map01/rgb/001160.png
# run1/map01/rgb/001161.png
# run1/map01/rgb/001162.png
# run1/map01/rgb/001163.png
# run1/map01/rgb/001164.png
# run1/map01/rgb/001165.png
# run1/map01/rgb/001166.png
# run1/map01/rgb/001167.png
# run1/map01/rgb/001168.png
# run1/map01/rgb/001169.png
# run1/map01/rgb/001170.png
# run1/map01/rgb/001171.png
# run1/map01/rgb/001172.png
# run1/map01/rgb/001173.png
# run1/map01/rgb/001174.png
# run1/map01/rgb/001175.png
# run1/map01/rgb/001176.png
# run1/map01/rgb/001177.png
# run1/map01/rgb/001178.png
# run1/map01/rgb/001179.png
# run1/map01/rgb/001180.png
# run1/map01/rgb/001181.png
# run1/map01/rgb/001182.png
# run1/map01/rgb/001183.png
# run1/map01/rgb/001184.png
# run1/map01/rgb/001185.png
# run1/map01/rgb/001186.png
# run1/map01/rgb/001187.png
# run1/map01/rgb/001188.png
# run1/map01/rgb/001189.png
# run1/map01/rgb/001190.png
# run1/map01/rgb/001191.png
# run1/map01/rgb/001192.png
# run1/map01/rgb/001193.png
# run1/map01/rgb/001194.png
# run1/map01/rgb/001195.png
# run1/map01/rgb/001196.png
# run1/map01/rgb/001197.png
# run1/map01/rgb/001198.png
# run1/map01/rgb/001199.png
# run1/map01/rgb/001200.png
# run1/map01/rgb/001201.png
# run1/map01/rgb/001202.png
# run1/map01/rgb/001203.png
# run1/map01/rgb/001204.png
# run1/map01/rgb/001205.png
# run1/map01/rgb/001206.png
# run1/map01/rgb/001207.png
# run1/map01/rgb/001208.png
# run1/map01/rgb/001209.png
# run1/map01/rgb/001210.png
# run1/map01/rgb/001211.png
# run1/map01/rgb/001212.png
# run1/map01/rgb/001213.png
# run1/map01/rgb/001214.png
# run1/map01/rgb/001215.png
# run1/map01/rgb/001216.png
# run1/map01/rgb/001217.png
# run1/map01/rgb/001218.png
# run1/map01/rgb/001219.png
# run1/map01/rgb/001220.png
# run1/map01/rgb/001221.png
# run1/map01/rgb/001222.png
# run1/map01/rgb/001223.png
# run1/map01/rgb/001224.png
# run1/map01/rgb/001225.png
# run1/map01/rgb/001226.png
# run1/map01/rgb/001227.png
# run1/map01/rgb/001228.png
# run1/map01/rgb/001229.png
# run1/map01/rgb/001230.png
# run1/map01/rgb/001231.png
# run1/map01/rgb/001232.png
# run1/map01/rgb/001233.png
# run1/map01/rgb/001234.png
# run1/map01/rgb/001235.png
# run1/map01/rgb/001236.png
# run1/map01/rgb/001237.png
# run1/map01/rgb/001238.png
# run1/map01/rgb/001239.png
# run1/map01/rgb/001240.png
# run1/map01/rgb/001241.png
# run1/map01/rgb/001242.png
# run1/map01/rgb/001243.png
# run1/map01/rgb/001244.png
# run1/map01/rgb/001245.png
# run1/map01/rgb/001246.png
# run1/map01/rgb/001247.png
# run1/map01/rgb/001248.png
# run1/map01/rgb/001249.png
# run1/map01/rgb/001250.png
# run1/map01/rgb/001251.png
# run1/map01/rgb/001252.png
# run1/map01/rgb/001253.png
# run1/map01/rgb/001254.png
# run1/map01/rgb/001255.png
# run1/map01/rgb/001256.png
# run1/map01/rgb/001257.png
# run1/map01/rgb/001258.png
# run1/map01/rgb/001259.png
# run1/map01/rgb/001260.png
# run1/map01/rgb/001261.png
# run1/map01/rgb/001262.png
# run1/map01/rgb/001263.png
# run1/map01/rgb/001264.png
# run1/map01/rgb/001265.png
# run1/map01/rgb/001266.png
# run1/map01/rgb/001267.png
# run1/map01/rgb/001268.png
# run1/map01/rgb/001269.png
# run1/map01/rgb/001270.png
# run1/map01/rgb/001271.png
# run1/map01/rgb/001272.png
# run1/map01/rgb/001273.png
# run1/map01/rgb/001274.png
# run1/map01/rgb/001275.png
# run1/map01/rgb/001276.png
# run1/map01/rgb/001277.png
# run1/map01/rgb/001278.png
# run1/map01/rgb/001279.png
# run1/map01/rgb/001280.png
# run1/map01/rgb/001281.png
# Epoch 1/10:   1%|                  | 5/991 [01:08<3:44:39, 13.67s/batch, batch_loss=41.4, batch_index=5, batch_size=256]
# run1/map01/rgb/001282.png
# run1/map01/rgb/001283.png
# run1/map01/rgb/001284.png
# run1/map01/rgb/001285.png
# run1/map01/rgb/001286.png
# run1/map01/rgb/001287.png
# run1/map01/rgb/001288.png
# run1/map01/rgb/001289.png
# run1/map01/rgb/001290.png
# run1/map01/rgb/001291.png
# run1/map01/rgb/001292.png
# run1/map01/rgb/001293.png
# run1/map01/rgb/001294.png
# run1/map01/rgb/001295.png
# run1/map01/rgb/001296.png
# run1/map01/rgb/001297.png
# run1/map01/rgb/001298.png
# run1/map01/rgb/001299.png
# run1/map01/rgb/001300.png
# run1/map01/rgb/001301.png
# run1/map01/rgb/001302.png
# run1/map01/rgb/001303.png
# run1/map01/rgb/001304.png
# run1/map01/rgb/001305.png
# run1/map01/rgb/001306.png
# run1/map01/rgb/001307.png
# run1/map01/rgb/001308.png
# run1/map01/rgb/001309.png
# run1/map01/rgb/001310.png
# run1/map01/rgb/001311.png
# run1/map01/rgb/001312.png
# run1/map01/rgb/001313.png
# run1/map01/rgb/001314.png
# run1/map01/rgb/001315.png
# run1/map01/rgb/001316.png
# run1/map01/rgb/001317.png
# run1/map01/rgb/001318.png
# run1/map01/rgb/001319.png
# run1/map01/rgb/001320.png
# run1/map01/rgb/001321.png
# run1/map01/rgb/001322.png
# run1/map01/rgb/001323.png
# run1/map01/rgb/001324.png
# run1/map01/rgb/001325.png
# run1/map01/rgb/001326.png
# run1/map01/rgb/001327.png
# run1/map01/rgb/001328.png
# run1/map01/rgb/001329.png
# run1/map01/rgb/001330.png
# run1/map01/rgb/001331.png
# run1/map01/rgb/001332.png
# run1/map01/rgb/001333.png
# run1/map01/rgb/001334.png
# run1/map01/rgb/001335.png
# run1/map01/rgb/001336.png
# run1/map01/rgb/001337.png
# run1/map01/rgb/001338.png
# run1/map01/rgb/001339.png
# run1/map01/rgb/001340.png
# run1/map01/rgb/001341.png
# run1/map01/rgb/001342.png
# run1/map01/rgb/001343.png
# run1/map01/rgb/001344.png
# run1/map01/rgb/001345.png
# run1/map01/rgb/001346.png
# run1/map01/rgb/001347.png
# run1/map01/rgb/001348.png
# run1/map01/rgb/001349.png
# run1/map01/rgb/001350.png
# run1/map01/rgb/001351.png
# run1/map01/rgb/001352.png
# run1/map01/rgb/001353.png
# run1/map01/rgb/001354.png
# run1/map01/rgb/001355.png
# run1/map01/rgb/001356.png
# run1/map01/rgb/001357.png
# run1/map01/rgb/001358.png
# run1/map01/rgb/001359.png
# run1/map01/rgb/001360.png
# run1/map01/rgb/001361.png
# run1/map01/rgb/001362.png
# run1/map01/rgb/001363.png
# run1/map01/rgb/001364.png
# run1/map01/rgb/001365.png
# run1/map01/rgb/001366.png
# run1/map01/rgb/001367.png
# run1/map01/rgb/001368.png
# run1/map01/rgb/001369.png
# run1/map01/rgb/001370.png
# run1/map01/rgb/001371.png
# run1/map01/rgb/001372.png
# run1/map01/rgb/001373.png
# run1/map01/rgb/001374.png
# run1/map01/rgb/001375.png
# run1/map01/rgb/001376.png
# run1/map01/rgb/001377.png
# run1/map01/rgb/001378.png
# run1/map01/rgb/001379.png
# run1/map01/rgb/001380.png
# run1/map01/rgb/001381.png
# run1/map01/rgb/001382.png
# run1/map01/rgb/001383.png
# run1/map01/rgb/001384.png
# run1/map01/rgb/001385.png
# run1/map01/rgb/001386.png
# run1/map01/rgb/001387.png
# run1/map01/rgb/001388.png
# run1/map01/rgb/001389.png
# run1/map01/rgb/001390.png
# run1/map01/rgb/001391.png
# run1/map01/rgb/001392.png
# run1/map01/rgb/001393.png
# run1/map01/rgb/001394.png
# run1/map01/rgb/001395.png
# run1/map01/rgb/001396.png
# run1/map01/rgb/001397.png
# run1/map01/rgb/001398.png
# run1/map01/rgb/001399.png
# run1/map01/rgb/001400.png
# run1/map01/rgb/001401.png
# run1/map01/rgb/001402.png
# run1/map01/rgb/001403.png
# run1/map01/rgb/001404.png
# run1/map01/rgb/001405.png
# run1/map01/rgb/001406.png
# run1/map01/rgb/001407.png
# run1/map01/rgb/001408.png
# run1/map01/rgb/001409.png
# run1/map01/rgb/001410.png
# run1/map01/rgb/001411.png
# run1/map01/rgb/001412.png
# run1/map01/rgb/001413.png
# run1/map01/rgb/001414.png
# run1/map01/rgb/001415.png
# run1/map01/rgb/001416.png
# run1/map01/rgb/001417.png
# run1/map01/rgb/001418.png
# run1/map01/rgb/001419.png
# run1/map01/rgb/001420.png
# run1/map01/rgb/001421.png
# run1/map01/rgb/001422.png
# run1/map01/rgb/001423.png
# run1/map01/rgb/001424.png
# run1/map01/rgb/001425.png
# run1/map01/rgb/001426.png
# run1/map01/rgb/001427.png
# run1/map01/rgb/001428.png
# run1/map01/rgb/001429.png
# run1/map01/rgb/001430.png
# run1/map01/rgb/001431.png
# run1/map01/rgb/001432.png
# run1/map01/rgb/001433.png
# run1/map01/rgb/001434.png
# run1/map01/rgb/001435.png
# run1/map01/rgb/001436.png
# run1/map01/rgb/001437.png
# run1/map01/rgb/001438.png
# run1/map01/rgb/001439.png
# run1/map01/rgb/001440.png
# run1/map01/rgb/001441.png
# run1/map01/rgb/001442.png
# run1/map01/rgb/001443.png
# run1/map01/rgb/001444.png
# run1/map01/rgb/001445.png
# run1/map01/rgb/001446.png
# run1/map01/rgb/001447.png
# run1/map01/rgb/001448.png
# run1/map01/rgb/001449.png
# run1/map01/rgb/001450.png
# run1/map01/rgb/001451.png
# run1/map01/rgb/001452.png
# run1/map01/rgb/001453.png
# run1/map01/rgb/001454.png
# run1/map01/rgb/001455.png
# run1/map01/rgb/001456.png
# run1/map01/rgb/001457.png
# run1/map01/rgb/001458.png
# run1/map01/rgb/001459.png
# run1/map01/rgb/001460.png
# run1/map01/rgb/001461.png
# run1/map01/rgb/001462.png
# run1/map01/rgb/001463.png
# run1/map01/rgb/001464.png
# run1/map01/rgb/001465.png
# run1/map01/rgb/001466.png
# run1/map01/rgb/001467.png
# run1/map01/rgb/001468.png
# run1/map01/rgb/001469.png
# run1/map01/rgb/001470.png
# run1/map01/rgb/001471.png
# run1/map01/rgb/001472.png
# run1/map01/rgb/001473.png
# run1/map01/rgb/001474.png
# run1/map01/rgb/001475.png
# run1/map01/rgb/001476.png
# run1/map01/rgb/001477.png
# run1/map01/rgb/001478.png
# run1/map01/rgb/001479.png
# run1/map01/rgb/001480.png
# run1/map01/rgb/001481.png
# run1/map01/rgb/001482.png
# run1/map01/rgb/001483.png
# run1/map01/rgb/001484.png
# run1/map01/rgb/001485.png
# run1/map01/rgb/001486.png
# run1/map01/rgb/001487.png
# run1/map01/rgb/001488.png
# run1/map01/rgb/001489.png
# run1/map01/rgb/001490.png
# run1/map01/rgb/001491.png
# run1/map01/rgb/001492.png
# run1/map01/rgb/001493.png
# run1/map01/rgb/001494.png
# run1/map01/rgb/001495.png
# run1/map01/rgb/001496.png
# run1/map01/rgb/001497.png
# run1/map01/rgb/001498.png
# run1/map01/rgb/001499.png
# run1/map01/rgb/001500.png
# run1/map01/rgb/001501.png
# run1/map01/rgb/001502.png
# run1/map01/rgb/001503.png
# run1/map01/rgb/001504.png
# run1/map01/rgb/001505.png
# run1/map01/rgb/001506.png
# run1/map01/rgb/001507.png
# run1/map01/rgb/001508.png
# run1/map01/rgb/001509.png
# run1/map01/rgb/001510.png
# run1/map01/rgb/001511.png
# run1/map01/rgb/001512.png
# run1/map01/rgb/001513.png
# run1/map01/rgb/001514.png
# run1/map01/rgb/001515.png
# run1/map01/rgb/001516.png
# run1/map01/rgb/001517.png
# run1/map01/rgb/001518.png
# run1/map01/rgb/001519.png
# run1/map01/rgb/001520.png
# run1/map01/rgb/001521.png
# run1/map01/rgb/001522.png
# run1/map01/rgb/001523.png
# run1/map01/rgb/001524.png
# run1/map01/rgb/001525.png
# run1/map01/rgb/001526.png
# run1/map01/rgb/001527.png
# run1/map01/rgb/001528.png
# run1/map01/rgb/001529.png
# run1/map01/rgb/001530.png
# run1/map01/rgb/001531.png
# run1/map01/rgb/001532.png
# run1/map01/rgb/001533.png
# run1/map01/rgb/001534.png
# run1/map01/rgb/001535.png
# run1/map01/rgb/001536.png
# run1/map01/rgb/001537.png
# Epoch 1/10:   1%|                  | 6/991 [01:22<3:42:36, 13.56s/batch, batch_loss=34.9, batch_index=6, batch_size=256]
# run1/map01/rgb/001538.png
# run1/map01/rgb/001539.png
# run1/map01/rgb/001540.png
# run1/map01/rgb/001541.png
# run1/map01/rgb/001542.png
# run1/map01/rgb/001543.png
# run1/map01/rgb/001544.png
# run1/map01/rgb/001545.png
# run1/map01/rgb/001546.png
# run1/map01/rgb/001547.png
# run1/map01/rgb/001548.png
# run1/map01/rgb/001549.png
# run1/map01/rgb/001550.png
# run1/map01/rgb/001551.png
# run1/map01/rgb/001552.png
# run1/map01/rgb/001553.png
# run1/map01/rgb/001554.png
# run1/map01/rgb/001555.png
# run1/map01/rgb/001556.png
# run1/map01/rgb/001557.png
# run1/map01/rgb/001558.png
# run1/map01/rgb/001559.png
# run1/map01/rgb/001560.png
# run1/map01/rgb/001561.png
# run1/map01/rgb/001562.png
# run1/map01/rgb/001563.png
# run1/map01/rgb/001564.png
# run1/map01/rgb/001565.png
# run1/map01/rgb/001566.png
# run1/map01/rgb/001567.png
# run1/map01/rgb/001568.png
# run1/map01/rgb/001569.png
# run1/map01/rgb/001570.png
# run1/map01/rgb/001571.png
# run1/map01/rgb/001572.png
# run1/map01/rgb/001573.png
# run1/map01/rgb/001574.png
# run1/map01/rgb/001575.png
# run1/map01/rgb/001576.png
# run1/map01/rgb/001577.png
# run1/map01/rgb/001578.png
# run1/map01/rgb/001579.png
# run1/map01/rgb/001580.png
# run1/map01/rgb/001581.png
# run1/map01/rgb/001582.png
# run1/map01/rgb/001583.png
# run1/map01/rgb/001584.png
# run1/map01/rgb/001585.png
# run1/map01/rgb/001586.png
# run1/map01/rgb/001587.png
# run1/map01/rgb/001588.png
# run1/map01/rgb/001589.png
# run1/map01/rgb/001590.png
# run1/map01/rgb/001591.png
# run1/map01/rgb/001592.png
# run1/map01/rgb/001593.png
# run1/map01/rgb/001594.png
# run1/map01/rgb/001595.png
# run1/map01/rgb/001596.png
# run1/map01/rgb/001597.png
# run1/map01/rgb/001598.png
# run1/map01/rgb/001599.png
# run1/map01/rgb/001600.png
# run1/map01/rgb/001601.png
# run1/map01/rgb/001602.png
# run1/map01/rgb/001603.png
# run1/map01/rgb/001604.png
# run1/map01/rgb/001605.png
# run1/map01/rgb/001606.png
# run1/map01/rgb/001607.png
# run1/map01/rgb/001608.png
# run1/map01/rgb/001609.png
# run1/map01/rgb/001610.png
# run1/map01/rgb/001611.png
# run1/map01/rgb/001612.png
# run1/map01/rgb/001613.png
# run1/map01/rgb/001614.png
# run1/map01/rgb/001615.png
# run1/map01/rgb/001616.png
# run1/map01/rgb/001617.png
# run1/map01/rgb/001618.png
# run1/map01/rgb/001619.png
# run1/map01/rgb/001620.png
# run1/map01/rgb/001621.png
# run1/map01/rgb/001622.png
# run1/map01/rgb/001623.png
# run1/map01/rgb/001624.png
# run1/map01/rgb/001625.png
# run1/map01/rgb/001626.png
# run1/map01/rgb/001627.png
# run1/map01/rgb/001628.png
# run1/map01/rgb/001629.png
# run1/map01/rgb/001630.png
# run1/map01/rgb/001631.png
# run1/map01/rgb/001632.png
# run1/map01/rgb/001633.png
# run1/map01/rgb/001634.png
# run1/map01/rgb/001635.png
# run1/map01/rgb/001636.png
# run1/map01/rgb/001637.png
# run1/map01/rgb/001638.png
# run1/map01/rgb/001639.png
# run1/map01/rgb/001640.png
# run1/map01/rgb/001641.png
# run1/map01/rgb/001642.png
# run1/map01/rgb/001643.png
# run1/map01/rgb/001644.png
# run1/map01/rgb/001645.png
# run1/map01/rgb/001646.png
# run1/map01/rgb/001647.png
# run1/map01/rgb/001648.png
# run1/map01/rgb/001649.png
# run1/map01/rgb/001650.png
# run1/map01/rgb/001651.png
# run1/map01/rgb/001652.png
# run1/map01/rgb/001653.png
# run1/map01/rgb/001654.png
# run1/map01/rgb/001655.png
# run1/map01/rgb/001656.png
# run1/map01/rgb/001657.png
# run1/map01/rgb/001658.png
# run1/map01/rgb/001659.png
# run1/map01/rgb/001660.png
# run1/map01/rgb/001661.png
# run1/map01/rgb/001662.png
# run1/map01/rgb/001663.png
# run1/map01/rgb/001664.png
# run1/map01/rgb/001665.png
# run1/map01/rgb/001666.png
# run1/map01/rgb/001667.png
# run1/map01/rgb/001668.png
# run1/map01/rgb/001669.png
# run1/map01/rgb/001670.png
# run1/map01/rgb/001671.png
# run1/map01/rgb/001672.png
# run1/map01/rgb/001673.png
# run1/map01/rgb/001674.png
# run1/map01/rgb/001675.png
# run1/map01/rgb/001676.png
# run1/map01/rgb/001677.png
# run1/map01/rgb/001678.png
# run1/map01/rgb/001679.png
# run1/map01/rgb/001680.png
# run1/map01/rgb/001681.png
# run1/map01/rgb/001682.png
# run1/map01/rgb/001683.png
# run1/map01/rgb/001684.png
# run1/map01/rgb/001685.png
# run1/map01/rgb/001686.png
# run1/map01/rgb/001687.png
# run1/map01/rgb/001688.png
# run1/map01/rgb/001689.png
# run1/map01/rgb/001690.png
# run1/map01/rgb/001691.png
# run1/map01/rgb/001692.png
# run1/map01/rgb/001693.png
# run1/map01/rgb/001694.png
# run1/map01/rgb/001695.png
# run1/map01/rgb/001696.png
# run1/map01/rgb/001697.png
# run1/map01/rgb/001698.png
# run1/map01/rgb/001699.png
# run1/map01/rgb/001700.png
# run1/map01/rgb/001701.png
# run1/map01/rgb/001702.png
# run1/map01/rgb/001703.png
# run1/map01/rgb/001704.png
# run1/map01/rgb/001705.png
# run1/map01/rgb/001706.png
# run1/map01/rgb/001707.png
# run1/map01/rgb/001708.png
# run1/map01/rgb/001709.png
# run1/map01/rgb/001710.png
# run1/map01/rgb/001711.png
# run1/map01/rgb/001712.png
# run1/map01/rgb/001713.png
# run1/map01/rgb/001714.png
# run1/map01/rgb/001715.png
# run1/map01/rgb/001716.png
# run1/map01/rgb/001717.png
# run1/map01/rgb/001718.png
# run1/map01/rgb/001719.png
# run1/map01/rgb/001720.png
# run1/map01/rgb/001721.png
# run1/map01/rgb/001722.png
# run1/map01/rgb/001723.png
# run1/map01/rgb/001724.png
# run1/map01/rgb/001725.png
# run1/map01/rgb/001726.png
# run1/map01/rgb/001727.png
# run1/map01/rgb/001728.png
# run1/map01/rgb/001729.png
# run1/map01/rgb/001730.png
# run1/map01/rgb/001731.png
# run1/map01/rgb/001732.png
# run1/map01/rgb/001733.png
# run1/map01/rgb/001734.png
# run1/map01/rgb/001735.png
# run1/map01/rgb/001736.png
# run1/map01/rgb/001737.png
# run1/map01/rgb/001738.png
# run1/map01/rgb/001739.png
# run1/map01/rgb/001740.png
# run1/map01/rgb/001741.png
# run1/map01/rgb/001742.png
# run1/map01/rgb/001743.png
# run1/map01/rgb/001744.png
# run1/map01/rgb/001745.png
# run1/map01/rgb/001746.png
# run1/map01/rgb/001747.png
# run1/map01/rgb/001748.png
# run1/map01/rgb/001749.png
# run1/map01/rgb/001750.png
# run1/map01/rgb/001751.png
# run1/map01/rgb/001752.png
# run1/map01/rgb/001753.png
# run1/map01/rgb/001754.png
# run1/map01/rgb/001755.png
# run1/map01/rgb/001756.png
# run1/map01/rgb/001757.png
# run1/map01/rgb/001758.png
# run1/map01/rgb/001759.png
# run1/map01/rgb/001760.png
# run1/map01/rgb/001761.png
# run1/map01/rgb/001762.png
# run1/map01/rgb/001763.png
# run1/map01/rgb/001764.png
# run1/map01/rgb/001765.png
# run1/map01/rgb/001766.png
# run1/map01/rgb/001767.png
# run1/map01/rgb/001768.png
# run1/map01/rgb/001769.png
# run1/map01/rgb/001770.png
# run1/map01/rgb/001771.png
# run1/map01/rgb/001772.png
# run1/map01/rgb/001773.png
# run1/map01/rgb/001774.png
# run1/map01/rgb/001775.png
# run1/map01/rgb/001776.png
# run1/map01/rgb/001777.png
# run1/map01/rgb/001778.png
# run1/map01/rgb/001779.png
# run1/map01/rgb/001780.png
# run1/map01/rgb/001781.png
# run1/map01/rgb/001782.png
# run1/map01/rgb/001783.png
# run1/map01/rgb/001784.png
# run1/map01/rgb/001785.png
# run1/map01/rgb/001786.png
# run1/map01/rgb/001787.png
# run1/map01/rgb/001788.png
# run1/map01/rgb/001789.png
# run1/map01/rgb/001790.png
# run1/map01/rgb/001791.png
# run1/map01/rgb/001792.png
# run1/map01/rgb/001793.png
# Epoch 1/10:   1%|▏                 | 7/991 [01:35<3:43:08, 13.61s/batch, batch_loss=30.5, batch_index=7, batch_size=256]
# run1/map01/rgb/001794.png
# run1/map01/rgb/001795.png
# run1/map01/rgb/001796.png
# run1/map01/rgb/001797.png
# run1/map01/rgb/001798.png
# run1/map01/rgb/001799.png
# run1/map01/rgb/001800.png
# run1/map01/rgb/001801.png
# run1/map01/rgb/001802.png
# ...
# run1/map02/rgb/002530.png
# run1/map02/rgb/002531.png
# run1/map02/rgb/002532.png
# run1/map02/rgb/002533.png
# run1/map02/rgb/002534.png
# run1/map02/rgb/002535.png
# run1/map02/rgb/002536.png
# run1/map02/rgb/002537.png
# run1/map02/rgb/002538.png
# run1/map02/rgb/002539.png
# run1/map02/rgb/002540.png
# run1/map02/rgb/002541.png
# run1/map02/rgb/002542.png
# run1/map02/rgb/002543.png
# run1/map02/rgb/002544.png
# run1/map02/rgb/002545.png
# run1/map02/rgb/002546.png
# run1/map02/rgb/002547.png
# run1/map02/rgb/002548.png
# run1/map02/rgb/002549.png
# run1/map02/rgb/002550.png
# run1/map02/rgb/002551.png
# run1/map02/rgb/002552.png
# run1/map02/rgb/002553.png
# run1/map02/rgb/002554.png
# run1/map02/rgb/002555.png
# run1/map02/rgb/002556.png
# run1/map02/rgb/002557.png
# run1/map02/rgb/002558.png
# run1/map02/rgb/002559.png
# run1/map02/rgb/002560.png
# run1/map02/rgb/002561.png
# run1/map02/rgb/002562.png
# run1/map02/rgb/002563.png
# run1/map02/rgb/002564.png
# run1/map02/rgb/002565.png
# run1/map02/rgb/002566.png
# run1/map02/rgb/002567.png
# run1/map02/rgb/002568.png
# run1/map02/rgb/002569.png
# run1/map02/rgb/002570.png
# run1/map02/rgb/002571.png
# run1/map02/rgb/002572.png
# run1/map02/rgb/002573.png
# run1/map02/rgb/002574.png
# run1/map02/rgb/002575.png
# run1/map02/rgb/002576.png
# run1/map02/rgb/002577.png
# run1/map02/rgb/002578.png
# run1/map02/rgb/002579.png
# run1/map02/rgb/002580.png
# run1/map02/rgb/002581.png
# run1/map02/rgb/002582.png
# run1/map02/rgb/002583.png
# run1/map02/rgb/002584.png
# run1/map02/rgb/002585.png
# run1/map02/rgb/002586.png
# run1/map02/rgb/002587.png
# run1/map02/rgb/002588.png
# run1/map02/rgb/002589.png
# run1/map02/rgb/002590.png
# run1/map02/rgb/002591.png
# run1/map02/rgb/002592.png
# run1/map02/rgb/002593.png
# run1/map02/rgb/002594.png
# run1/map02/rgb/002595.png
# run1/map02/rgb/002596.png
# run1/map02/rgb/002597.png
# run1/map02/rgb/002598.png
# run1/map02/rgb/002599.png
# Epoch 1/10:   1%|▏               | 10/991 [02:31<4:30:18, 16.53s/batch, batch_loss=21.6, batch_index=10, batch_size=256]
# run1/map02/rgb/002600.png
# run1/map02/rgb/002601.png
# run1/map02/rgb/002602.png
# run1/map02/rgb/002603.png
# run1/map02/rgb/002604.png
# run1/map02/rgb/002605.png
# run1/map02/rgb/002606.png
# run1/map02/rgb/002607.png
# run1/map02/rgb/002608.png
# run1/map02/rgb/002609.png
# run1/map02/rgb/002610.png
# run1/map02/rgb/002611.png
# run1/map02/rgb/002612.png
# run1/map02/rgb/002613.png
# run1/map02/rgb/002614.png
# run1/map02/rgb/002615.png
# run1/map02/rgb/002616.png
# run1/map02/rgb/002617.png
# run1/map02/rgb/002618.png
# run1/map02/rgb/002619.png
# run1/map02/rgb/002620.png
# run1/map02/rgb/002621.png
# run1/map02/rgb/002622.png
# run1/map02/rgb/002623.png
# run1/map02/rgb/002624.png
# run1/map02/rgb/002625.png
# run1/map02/rgb/002626.png
# run1/map02/rgb/002627.png
# run1/map02/rgb/002628.png
# run1/map02/rgb/002629.png
# run1/map02/rgb/002630.png
# run1/map02/rgb/002631.png
# run1/map02/rgb/002632.png
# run1/map02/rgb/002633.png
# run1/map02/rgb/002634.png
# run1/map02/rgb/002635.png
# run1/map02/rgb/002636.png
# run1/map02/rgb/002637.png
# run1/map02/rgb/002638.png
# run1/map02/rgb/002639.png
# run1/map02/rgb/002640.png
# run1/map02/rgb/002641.png
# run1/map02/rgb/002642.png
# run1/map02/rgb/002643.png
# run1/map02/rgb/002644.png
# run1/map02/rgb/002645.png
# run1/map02/rgb/002646.png
# run1/map02/rgb/002647.png
# run1/map02/rgb/002648.png
# run1/map02/rgb/002649.png
# run1/map02/rgb/002650.png
# run1/map02/rgb/002651.png
# run1/map02/rgb/002652.png
# run1/map02/rgb/002653.png
# run1/map02/rgb/002654.png
# run1/map02/rgb/002655.png
# run1/map02/rgb/002656.png
# run1/map02/rgb/002657.png
# run1/map02/rgb/002658.png
# run1/map02/rgb/002659.png
# run1/map02/rgb/002660.png
# run1/map02/rgb/002661.png
# run1/map02/rgb/002662.png
# run1/map02/rgb/002663.png
# run1/map02/rgb/002664.png
# run1/map02/rgb/002665.png
# run1/map02/rgb/002666.png
# run1/map02/rgb/002667.png
# run1/map02/rgb/002668.png
# run1/map02/rgb/002669.png
# run1/map02/rgb/002670.png
# run1/map02/rgb/002671.png
# run1/map02/rgb/002672.png
# run1/map02/rgb/002673.png
# run1/map02/rgb/002674.png
# run1/map02/rgb/002675.png
# run1/map02/rgb/002676.png
# run1/map02/rgb/002677.png
# run1/map02/rgb/002678.png
# run1/map02/rgb/002679.png
# run1/map02/rgb/002680.png
# run1/map02/rgb/002681.png
# run1/map02/rgb/002682.png
# run1/map02/rgb/002683.png
# run1/map02/rgb/002684.png
# run1/map02/rgb/002685.png
# run1/map02/rgb/002686.png
# run1/map02/rgb/002687.png
# run1/map02/rgb/002688.png
# run1/map02/rgb/002689.png
# run1/map02/rgb/002690.png
# run1/map02/rgb/002691.png
# run1/map02/rgb/002692.png
# run1/map02/rgb/002693.png
# run1/map02/rgb/002694.png
# run1/map02/rgb/002695.png
# run1/map02/rgb/002696.png
# run1/map02/rgb/002697.png
# run1/map02/rgb/002698.png
# run1/map02/rgb/002699.png
# run1/map02/rgb/002700.png
# run1/map02/rgb/002701.png
# run1/map02/rgb/002702.png
# run1/map02/rgb/002703.png
# run1/map02/rgb/002704.png
# run1/map02/rgb/002705.png
# run1/map02/rgb/002706.png
# run1/map02/rgb/002707.png
# run1/map02/rgb/002708.png
# run1/map02/rgb/002709.png
# run1/map02/rgb/002710.png
# run1/map02/rgb/002711.png
# run1/map02/rgb/002712.png
# run1/map02/rgb/002713.png
# run1/map02/rgb/002714.png
# run1/map02/rgb/002715.png
# run1/map02/rgb/002716.png
# run1/map02/rgb/002717.png
# run1/map02/rgb/002718.png
# run1/map02/rgb/002719.png
# run1/map02/rgb/002720.png
# run1/map02/rgb/002721.png
# run1/map02/rgb/002722.png
# run1/map02/rgb/002723.png
# run1/map02/rgb/002724.png
# run1/map02/rgb/002725.png
# run1/map02/rgb/002726.png
# run1/map02/rgb/002727.png
# run1/map02/rgb/002728.png
# run1/map02/rgb/002729.png
# run1/map02/rgb/002730.png
# run1/map02/rgb/002731.png
# run1/map02/rgb/002732.png
# run1/map02/rgb/002733.png
# run1/map02/rgb/002734.png
# run1/map02/rgb/002735.png
# run1/map02/rgb/002736.png
# run1/map02/rgb/002737.png
# run1/map02/rgb/002738.png
# run1/map02/rgb/002739.png
# run1/map02/rgb/002740.png
# run1/map02/rgb/002741.png
# run1/map02/rgb/002742.png
# run1/map02/rgb/002743.png
# run1/map02/rgb/002744.png
# run1/map02/rgb/002745.png
# run1/map02/rgb/002746.png
# run1/map02/rgb/002747.png
# run1/map02/rgb/002748.png
# run1/map02/rgb/002749.png
# run1/map02/rgb/002750.png
# run1/map02/rgb/002751.png
# run1/map02/rgb/002752.png
# run1/map02/rgb/002753.png
# run1/map02/rgb/002754.png
# run1/map02/rgb/002755.png
# run1/map02/rgb/002756.png
# run1/map02/rgb/002757.png
# run1/map02/rgb/002758.png
# run1/map02/rgb/002759.png
# run1/map02/rgb/002760.png
# run1/map02/rgb/002761.png
# run1/map02/rgb/002762.png
# run1/map02/rgb/002763.png
# run1/map02/rgb/002764.png
# run1/map02/rgb/002765.png
# run1/map02/rgb/002766.png
# run1/map02/rgb/002767.png
# run1/map02/rgb/002768.png
# run1/map02/rgb/002769.png
# run1/map02/rgb/002770.png
# run1/map02/rgb/002771.png
# run1/map02/rgb/002772.png
# run1/map02/rgb/002773.png
# run1/map02/rgb/002774.png
# run1/map02/rgb/002775.png
# run1/map02/rgb/002776.png
# run1/map02/rgb/002777.png
# run1/map02/rgb/002778.png
# run1/map02/rgb/002779.png
# run1/map02/rgb/002780.png
# run1/map02/rgb/002781.png
# run1/map02/rgb/002782.png
# run1/map02/rgb/002783.png
# run1/map02/rgb/002784.png
# run1/map02/rgb/002785.png
# run1/map02/rgb/002786.png
# Epoch 1/10:   1%|▏               | 10/991 [02:43<4:26:40, 16.31s/batch, batch_loss=21.6, batch_index=10, batch_size=256]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 25
#      23 running_loss = 0.0
#      24 progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", unit="batch")
# ---> 25 for batch_idx, batch in enumerate(progress_bar):
#      26     prev_motion, next_motion, previous_seg, previous_dep = batch["prev_motion"], batch["next_motion"], batch["previous_seg"], batch["previous_dep"]
#      27     prev_motion, next_motion, previous_seg, previous_dep = prev_motion.to(device), next_motion.to(device), previous_seg.to(device), previous_dep.to(device)
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[44], line 89, in DoomMotionDataset.__getitem__(self, idx)
#      87 # run1/map01/rgb/000002.png
#      88 if os.path.exists(DATADIR + prev_filename):
# ---> 89     seg = self.fullSegmentationFormat(prev_filename)
#      90     #print(f"seg shape: {seg.shape}")
#      91     dep = self.fullDepthFormat(prev_filename)
#
# Cell In[44], line 18, in DoomMotionDataset.fullSegmentationFormat(self, rgb_filename)
#      16     return seg_image
#      17 seg_class_map = self.color_to_index(seg_image)
# ---> 18 seg_class_one_hot = functions.one_hot(seg_class_map, num_classes=4).to(dtype=torch.float).permute(2, 0, 1)
#      19 return seg_class_one_hot
#
# KeyboardInterrupt:
# Epoch 1/10:   0%|                            | 0/991 [00:14<?, ?batch/s, batch_loss=32.6, batch_index=1, batch_size=256]
# Epoch 1/10:   0%|                  | 1/991 [00:14<3:58:23, 14.45s/batch, batch_loss=32.6, batch_index=1, batch_size=256]
# Epoch 1/10:   0%|                  | 1/991 [00:29<3:58:23, 14.45s/batch, batch_loss=32.5, batch_index=2, batch_size=256]
# Epoch 1/10:   0%|                  | 2/991 [00:29<4:02:24, 14.71s/batch, batch_loss=32.5, batch_index=2, batch_size=256]
# Epoch 1/10:   0%|                  | 2/991 [00:43<4:02:24, 14.71s/batch, batch_loss=26.8, batch_index=3, batch_size=256]
# Epoch 1/10:   0%|                  | 3/991 [00:43<3:57:47, 14.44s/batch, batch_loss=26.8, batch_index=3, batch_size=256]
# Epoch 1/10:   0%|                  | 3/991 [00:57<3:57:47, 14.44s/batch, batch_loss=12.5, batch_index=4, batch_size=256]
# Epoch 1/10:   0%|                  | 4/991 [00:57<3:53:30, 14.19s/batch, batch_loss=12.5, batch_index=4, batch_size=256]
# Epoch 1/10:   0%|                    | 4/991 [01:11<3:53:30, 14.19s/batch, batch_loss=42, batch_index=5, batch_size=256]
# Epoch 1/10:   1%|                    | 5/991 [01:11<3:55:50, 14.35s/batch, batch_loss=42, batch_index=5, batch_size=256]
# Epoch 1/10:   1%|                  | 5/991 [01:24<3:55:50, 14.35s/batch, batch_loss=34.9, batch_index=6, batch_size=256]
# Epoch 1/10:   1%|                  | 6/991 [01:24<3:46:56, 13.82s/batch, batch_loss=34.9, batch_index=6, batch_size=256]
# Epoch 1/10:   1%|                    | 6/991 [01:38<3:46:56, 13.82s/batch, batch_loss=31, batch_index=7, batch_size=256]
# Epoch 1/10:   1%|▏                   | 7/991 [01:38<3:46:50, 13.83s/batch, batch_loss=31, batch_index=7, batch_size=256]
# Epoch 1/10:   1%|▏                   | 7/991 [01:41<3:57:25, 14.48s/batch, batch_loss=31, batch_index=7, batch_size=256]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 25
#      23 running_loss = 0.0
#      24 progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", unit="batch")
# ---> 25 for batch_idx, batch in enumerate(progress_bar):
#      26     prev_motion, next_motion, previous_seg, previous_dep = batch["prev_motion"], batch["next_motion"], batch["previous_seg"], batch["previous_dep"]
#      27     prev_motion, next_motion, previous_seg, previous_dep = prev_motion.to(device), next_motion.to(device), previous_seg.to(device), previous_dep.to(device)
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /shared/storage/cs/studentscratch/js3921/python_environments/envs/project_env_cuda/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[10], line 116, in DoomMotionDataset.__getitem__(self, idx)
#     114 prev_motion_vectors = torch.tensor(prev_motion_vectors, dtype=torch.float32)
#     115 next_motion_vectors = torch.tensor(next_motion_vectors, dtype=torch.float32)
# --> 116 prev_seg = torch.stack(prev_seg)
#     117 prev_dep = torch.stack(prev_dep)
#     119 return {"prev_motion" : prev_motion_vectors, "next_motion" : next_motion_vectors, "previous_seg" : prev_seg, "previous_dep" : prev_dep}
#
# RuntimeError: stack expects a non-empty TensorList

# %%
device = (torch.device("cuda" if torch.cuda.is_available() else "cpu"))
criterion = torch.nn.MSELoss()
model = NeuralNetwork(batch_size, input_window, prediction_window, device=device).to(device)
model.load_state_dict(torch.load("multimodal_seq2seq.pth", weights_only=True))

test_dataset = DoomMotionDataset(coco_test, TEST_RUN, input_window, prediction_window)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

model.eval()  # Set the model to evaluation mode
running_loss = 0.0


progress_bar = tqdm(test_loader, desc="Testing", unit="batch")

with torch.no_grad():  # Disable gradient calculations for evaluation
    for batch_idx, batch in enumerate(progress_bar):
        prev_motion, next_motion, previous_seg, previous_dep = batch["prev_motion"], batch["next_motion"], batch["previous_seg"], batch["previous_dep"]
        prev_motion, next_motion, previous_seg, previous_dep = prev_motion.to(device), next_motion.to(device), previous_seg.to(device), previous_dep.to(device)

        if prev_motion.shape[0] != next_motion.shape[0]:
                continue
            
        outputs = model(previous_seg, previous_dep, prev_motion)
        outputs = outputs.permute(1, 0, 2)

        if outputs.size(0) != next_motion.size(0):
            continue
        
        loss = criterion(outputs, next_motion)
        
        running_loss += loss.item()
        
        progress_bar.set_postfix({
            "batch_loss": loss.item(),
            "batch_index": batch_idx + 1,
            "batch_size": prev_motion.size(0)
        })

# Average loss over all batches
test_loss = running_loss / len(test_loader)
print(f"Test Loss: {test_loss:.4f}")
